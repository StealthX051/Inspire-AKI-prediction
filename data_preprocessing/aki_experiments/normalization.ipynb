# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
df = pd.read_csv('/home/server/Projects/data/AKI/aki_data_trainable.csv')

# %%
cols_to_norm = ['age', 'height', 'weight', 'BSA', 'BMI', 'booking_case_length', 'num_card_events',  'last_preop_scr',
       'min_preop_scr', 'preop_total_protein', 'preop_sodium',
       'preop_potassium', 'preop_platelet', 'preop_glucose', 'preop_wbc',
       'preop_alt', 'preop_chloride', 'preop_lymphocyte', 'preop_phosphorus',
       'preop_albumin', 'preop_fibrinogen', 'preop_creatinine', 'preop_ptinr',
       'preop_total_bilirubin', 'preop_alp', 'preop_aptt', 'preop_calcium',
       'preop_bun', 'preop_ast', 'preop_crp', 'preop_hb', 'preop_hct',
       'preop_seg', 'op_len']

# %%
scaler = StandardScaler()
df[cols_to_norm] = scaler.fit_transform(df[cols_to_norm])

# %%
df["booking_case_length"].sum()
# Out:
# -1.057287590811029e-11

# %%
df
# Out:
#             age    sex    height    weight  asa  emop       BSA       BMI  \
# 0      0.120836   True  0.827501  0.195006  4.0   1.0  0.397905 -0.331433
# 1     -0.883393   True -0.007595  0.195006  1.0   1.0  0.001766  0.340982
# 2     -0.883393   True  1.953946  0.195006  1.0   1.0  0.670714 -1.005268
# 3      1.125065   True -0.007595  0.007661  3.0   1.0  0.001766  0.340982
# 4     -0.548650  False -0.298944 -1.094125  3.0   1.0 -1.005392 -1.152392
# ...         ...    ...       ...       ...  ...   ...       ...       ...
# 51269  0.455579   True -0.298944 -0.234704  2.0   0.0 -0.241194 -0.069026
# 51270  0.455579   True  0.264279  0.624716  3.0   0.0  0.608445  0.561694
# 51271  0.790322  False -0.862166  0.195006  2.0   0.0 -0.026826  0.934300
# 51272  0.790322   True  1.390724  0.624716  2.0   0.0  0.895687 -0.229983
# 51273 -1.552878   True  1.953946  0.624716  1.0   0.0  1.036230 -0.577272
#
#        booking_case_length  num_card_events  ...  preop_ast_isna  \
# 0                 0.132805        -0.220850  ...           False
# 1                -1.027835        -0.220850  ...           False
# 2                 0.519685        -0.220850  ...           False
# 3                 1.448196         0.091291  ...           False
# 4                 0.945252         0.403433  ...           False
# ...                    ...              ...  ...             ...
# 51269            -0.524891        -0.220850  ...           False
# 51270             0.403621         5.553767  ...           False
# 51271            -0.486203        -0.220850  ...           False
# 51272            -1.221274        13.513374  ...           False
# 51273            -1.182586        -0.220850  ...           False
#
#        preop_crp_isna  preop_hb_isna  preop_hct_isna  preop_seg_isna  \
# 0                True          False           False           False
# 1               False          False           False           False
# 2               False          False           False           False
# 3               False          False           False           False
# 4               False          False           False           False
# ...               ...            ...             ...             ...
# 51269           False          False           False           False
# 51270           False          False           False           False
# 51271           False          False           False           False
# 51272           False          False           False           False
# 51273           False          False           False           False
#
#        aki_isna  op_len_isna   aki  aki_boolean  aki_positive
# 0         False        False  0.24        False          0.24
# 1         False        False  0.17        False          0.17
# 2         False        False  0.41         True          0.41
# 3         False        False -1.35        False          0.00
# 4         False        False -0.30        False          0.00
# ...         ...          ...   ...          ...           ...
# 51269     False        False  0.00        False          0.00
# 51270     False        False  0.00        False          0.00
# 51271     False        False -0.09        False          0.00
# 51272     False        False -0.06        False          0.00
# 51273     False        False -0.21        False          0.00
#
# [51274 rows x 78 columns]
